# %%
color = input("Enter the list of color: ")
list = color.split(",")

if len(list) >= 2:
  print("The first color of the list is:",(list[0]))
  print("The last color of the list is:",(list[-1]))
else:
  print("Enter more than two colors:")
# Out:
# Enter the list of color: red,black,white,blue,green
# The first color of the list is: red
# The last color of the list is: green
