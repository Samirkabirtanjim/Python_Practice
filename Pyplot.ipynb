# %%
from matplotlib import pyplot as plt

x = input("Enter X-Level: ")
y = input("Enter Y-Level: ")

xx = [float(value) for value in x.split(",")]
yy = [float(value) for value in y.split(",")]

plt.bar(xx, yy)
plt.title("Learning")
plt.xlabel("X Level")
plt.ylabel("Y Level")
plt.show()
# Out:
# Enter X-Level: 1,2,3
# Enter Y-Level: 4,5,1
