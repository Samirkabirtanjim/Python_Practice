# %%
filename = input("Enter your file name: ")
file_name = filename.split(".")
print("Extension of your file name is: "+(file_name[-1]))
# Out:
# Enter your file name: hello.py
# Extension of your file name is: py
