# %%
num = input("Enter sequence-number using comma: ")
list = num.split(",")
tuples = tuple(list)
print("List: ",list)
print("Tuple: ",tuples)
# Out:
# Enter sequence-number using comma: 2, 1, 1, 9, 0, 2, 0, 5, 2
# List:  ['2', ' 1', ' 1', ' 9', ' 0', ' 2', ' 0', ' 5', ' 2']
# Tuple:  ('2', ' 1', ' 1', ' 9', ' 0', ' 2', ' 0', ' 5', ' 2')
