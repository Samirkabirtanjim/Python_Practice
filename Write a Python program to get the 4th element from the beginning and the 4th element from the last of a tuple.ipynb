# %%
number = input("Enter numbers: ")
number_tuple = number.split(",")
tuples = tuple(number_tuple)
print("Entered numbers: ",tuples)

print("The fourth component from the start  " ,tuples[3])
print("The final member of a tuple, the fourth element" ,tuples[-4])
# Out:
# Enter numbers: s,h,o,p,o,n,2,1,1,9,0
# Entered numbers:  ('s', 'h', 'o', 'p', 'o', 'n', '2', '1', '1', '9', '0')
# The fourth component from the start   p
# The final member of a tuple, the fourth element 1
