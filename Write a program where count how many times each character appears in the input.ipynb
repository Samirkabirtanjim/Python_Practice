# %%
word = input("Enter any words: ").lower()
Alphabet = [chr(i) for i in range(ord('a'),ord('z')+1)]

for letter in Alphabet:
  if word.count(letter)>0:
    print(f"{letter} : {word.count(letter)}")
# Out:
# Enter any words: Samir Kabir Tanjim
# a : 3
# b : 1
# i : 3
# j : 1
# k : 1
# m : 2
# n : 1
# r : 2
# s : 1
# t : 1
